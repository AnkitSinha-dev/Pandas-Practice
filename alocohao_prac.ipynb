# %%
import pandas as pd

# %%
drinks = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
es=drinks.groupby('continent').beer_servings.mean()
es
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').beer_servings.describe()
# Out:
#            count        mean        std   min     25%    50%     75%    max
# continent
# AF          53.0   61.471698  80.557816   0.0   15.00   32.0   76.00  376.0
# AS          44.0   37.045455  49.469725   0.0    4.25   17.5   60.50  247.0
# EU          45.0  193.777778  99.631569   0.0  127.00  219.0  270.00  361.0
# OC          16.0   89.687500  96.641412   0.0   21.00   52.5  125.75  306.0
# SA          12.0  175.083333  65.242845  93.0  129.50  162.5  198.00  333.0

# %%
drinks.groupby('continent').mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %%
drinks.groupby('continent').median()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75
# SA                                 6.85

# %%
drinks.groupby('continent').spirit_servings.agg(['mean', 'min', 'max'])
# Out:
#                  mean  min  max
# continent
# AF          16.339623    0  152
# AS          60.840909    0  326
# EU         132.555556    0  373
# OC          58.437500    0  254
# SA         114.750000   25  302

# %%
g=drinks.groupby('continent')
g.get_group('AF')
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# 2                     Algeria             25                0             14
# 4                      Angola            217               57             45
# 18                      Benin             34                4             13
# 22                   Botswana            173               35             35
# 26               Burkina Faso             25                7              7
# 27                    Burundi             88                0              0
# 28              Cote d'Ivoire             37                1              7
# 29                 Cabo Verde            144               56             16
# 31                   Cameroon            147                1              4
# 33   Central African Republic             17                2              1
# 34                       Chad             15                1              1
# ...

# %%
for conti,conti_g in g:
    print(conti)
    print(conti_g)
# Out:
# AF
#                       country  beer_servings  spirit_servings  wine_servings  \
# 2                     Algeria             25                0             14
# 4                      Angola            217               57             45
# 18                      Benin             34                4             13
# 22                   Botswana            173               35             35
# 26               Burkina Faso             25                7              7
# 27                    Burundi             88                0              0
# 28              Cote d'Ivoire             37                1              7
# 29                 Cabo Verde            144               56             16
# 31                   Cameroon            147                1              4
# 33   Central African Republic             17                2              1
# 34                       Chad             15                1              1
# ...

# %%
drinks[drinks['country']=='India']
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 77   India              9              114              0
#
#     total_litres_of_pure_alcohol continent
# 77                           2.2        AS

# %%
g.get_group('AS')
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 12                Bahrain             42               63              7
# 13             Bangladesh              0                0              0
# 19                 Bhutan             23                0              0
# 24                 Brunei             31                2              1
# 30               Cambodia             57               65              1
# 36                  China             79              192              8
# 46            North Korea              0                0              0
# 77                  India              9              114              0
# 78              Indonesia              5                1              0
# 79                   Iran              0                0              0
# 80                   Iraq              9                3              0
# ...

# %%
drinks[drinks.country.str.startswith('Indo')]
# Out:
#       country  beer_servings  spirit_servings  wine_servings  \
# 78  Indonesia              5                1              0
#
#     total_litres_of_pure_alcohol continent
# 78                           0.1        AS

# %%
drinks[(drinks['spirit_servings']==drinks['spirit_servings'].max())]
# Out:
#     country  beer_servings  spirit_servings  wine_servings  \
# 68  Grenada            199              438             28
#
#     total_litres_of_pure_alcohol continent
# 68                          11.9       NaN

# %%
drinks.sort_values(by=['beer_servings','spirit_servings'],ascending=[False,False]).head(10)
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 117         Namibia            376                3              1
# 45   Czech Republic            361              170            134
# 62            Gabon            347               98             59
# 65          Germany            346              117            175
# 98        Lithuania            343              244             56
# 135          Poland            343              215             56
# 188       Venezuela            333              100              3
# 81          Ireland            313              118            165
# 129           Palau            306               63             23
# 140         Romania            297              122            167
#
#      total_litres_of_pure_alcohol continent
# 117                           6.8        AF
# 45                           11.8        EU
# 62                            8.9        AF
# 65                           11.3        EU
# ...

# %%
drinks.country.value_counts().count()
# Out:
# 193
